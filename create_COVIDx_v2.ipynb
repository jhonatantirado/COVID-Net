# %%
import numpy as np
import pandas as pd
import os
import random 
from shutil import copyfile
import pydicom as dicom
import cv2

# %%
# set parameters here
savepath = 'data'
seed = 0
np.random.seed(seed) # Reset the seed so all runs are the same.
random.seed(seed)
MAXVAL = 255  # Range [0 255]

# path to covid-19 dataset from https://github.com/ieee8023/covid-chestxray-dataset
imgpath = '../covid-chestxray-dataset/images' 
csvpath = '../covid-chestxray-dataset/metadata.csv'

# path to https://www.kaggle.com/c/rsna-pneumonia-detection-challenge
kaggle_datapath = 'rsna-pneumonia-detection-challenge'
kaggle_csvname = 'stage_2_detailed_class_info.csv' # get all the normal from here
kaggle_csvname2 = 'stage_2_train_labels.csv' # get all the 1s from here since 1 indicate pneumonia
kaggle_imgpath = 'stage_2_train_images'

# parameters for COVIDx dataset
train = []
test = []
test_count = {'normal': 0, 'pneumonia': 0, 'COVID-19': 0}
train_count = {'normal': 0, 'pneumonia': 0, 'COVID-19': 0}

mapping = dict()
mapping['COVID-19'] = 'COVID-19'
mapping['SARS'] = 'pneumonia'
mapping['MERS'] = 'pneumonia'
mapping['Streptococcus'] = 'pneumonia'
mapping['Normal'] = 'normal'
mapping['Lung Opacity'] = 'pneumonia'
mapping['1'] = 'pneumonia'

# train/test split config
split = 0.1

# %%
# adapted from https://github.com/mlmed/torchxrayvision/blob/master/torchxrayvision/datasets.py#L814
csv = pd.read_csv(csvpath, nrows=None)
idx_pa = csv["view"] == "PA"  # Keep only the PA view
csv = csv[idx_pa]

pneumonias = ["COVID-19", "SARS", "MERS", "ARDS", "Streptococcus"]
pathologies = ["Pneumonia","Viral Pneumonia", "Bacterial Pneumonia", "No Finding"] + pneumonias
pathologies = sorted(pathologies)

# %%
print (csv)
# Out:
#      patientid  offset  sex   age       finding survival intubated  \
# 0            2     0.0    M  65.0      COVID-19        Y       NaN
# 1            2     3.0    M  65.0      COVID-19        Y       NaN
# 2            2     5.0    M  65.0      COVID-19        Y       NaN
# 3            2     6.0    M  65.0      COVID-19        Y       NaN
# 4            4     0.0    F  52.0      COVID-19      NaN       NaN
# 5            4     5.0    F  52.0      COVID-19      NaN       NaN
# 6            5     NaN  NaN   NaN          ARDS      NaN         Y
# 7            6     0.0  NaN   NaN      COVID-19      NaN         Y
# 8            6     4.0  NaN   NaN      COVID-19      NaN         Y
# 9            3     4.0    M  74.0          SARS        N       NaN
# 10           3     9.0    M  74.0          SARS        N       NaN
# 11           3    10.0    M  74.0          SARS        N       NaN
# 12           7     7.0    F  29.0          SARS        Y       NaN
# 13           7    12.0    F  29.0          SARS        Y       NaN
# 14           8     9.0    F  42.0          SARS      NaN       NaN
# 15           9     5.0    F  46.0          SARS      NaN       NaN
# 16           9    12.0    F  46.0          SARS      NaN       NaN
# 17          10    17.0    F  73.0          SARS        N       NaN
# 18          10    19.0    F  73.0          SARS        N       NaN
# 19          10    27.0    F  73.0          SARS        N       NaN
# 20          11     0.0    M  56.0      COVID-19        Y       NaN
# 21          12     7.0    M  42.0      COVID-19        Y       NaN
# 22          13     4.0    M  35.0      COVID-19        Y       NaN
# 24          13     7.0    M  35.0      COVID-19        Y       NaN
# 26          13     9.0    M  35.0      COVID-19        Y       NaN
# 27          13    10.0    M  35.0      COVID-19        Y       NaN
# 29          14     0.0    F   NaN      COVID-19      NaN       NaN
# 30          15     0.0    M   NaN      COVID-19      NaN       NaN
# 31          15     4.0    M   NaN      COVID-19      NaN       NaN
# 32          15     7.0    M   NaN      COVID-19      NaN       NaN
# ..         ...     ...  ...   ...           ...      ...       ...
# 192         99     0.0    M  55.0      COVID-19      NaN       NaN
# 193        100     NaN    F  62.0    Klebsiella      NaN       NaN
# 194        101     NaN    F  40.0  Pneumocystis        N       NaN
# 195        101     NaN    F  40.0  Pneumocystis        N       NaN
# 196        101     NaN    F  40.0  Pneumocystis        N       NaN
# 197        102     NaN  NaN   NaN  Pneumocystis      NaN       NaN
# 198        103     NaN  NaN   NaN  Pneumocystis      NaN       NaN
# 199        104     NaN  NaN   NaN  Pneumocystis      NaN       NaN
# 200        105     NaN    M   NaN  Pneumocystis      NaN       NaN
# 202        106     NaN    M  50.0  Pneumocystis      NaN       NaN
# 203        107     NaN    M  25.0  Pneumocystis      NaN       NaN
# 204        108     NaN    M  50.0  Pneumocystis      NaN       NaN
# 205        109     NaN    M  70.0  Pneumocystis      NaN       NaN
# 206        109     NaN    M  70.0  Pneumocystis      NaN       NaN
# 207        110     NaN    M  60.0    Legionella      NaN       NaN
# 208        111     NaN    M  45.0    Legionella      NaN       NaN
# 209        112     0.0  NaN   NaN      COVID-19        Y       NaN
# 210        112     7.0  NaN   NaN      COVID-19        Y       NaN
# 211        113     0.0  NaN   NaN      COVID-19      NaN       NaN
# 212        113    10.0  NaN   NaN      COVID-19      NaN       NaN
# 213        114     0.0  NaN   NaN      COVID-19      NaN       NaN
# 214        114     7.0  NaN   NaN      COVID-19      NaN       NaN
# 215        115     0.0  NaN   NaN      COVID-19      NaN       NaN
# 216        115     5.0  NaN   NaN      COVID-19      NaN       NaN
# 220        117     0.0    M  50.0      COVID-19      NaN       NaN
# 225        118     3.0    F  71.0      COVID-19        Y       NaN
# 250        139     2.0    M  45.0      COVID-19      NaN       NaN
# 253        140     NaN    F  60.0      COVID-19      NaN       NaN
# 254        141     NaN    M  65.0      COVID-19      NaN       NaN
# 267        149    10.0    M  40.0      COVID-19      NaN         Y
#
#      temperature  pO2 saturation  leukocyte count  ...              date  \
# 0            NaN             NaN              NaN  ...  January 22, 2020
# 1            NaN             NaN              NaN  ...  January 25, 2020
# 2            NaN             NaN              NaN  ...  January 27, 2020
# 3            NaN             NaN              NaN  ...  January 28, 2020
# 4            NaN             NaN              NaN  ...  January 25, 2020
# 5            NaN             NaN              NaN  ...  January 30, 2020
# 6            NaN             NaN              NaN  ...              2017
# 7            NaN             NaN              NaN  ...              2020
# 8            NaN             NaN              NaN  ...              2020
# 9            NaN             NaN              NaN  ...              2004
# 10           NaN             NaN              NaN  ...              2004
# 11           NaN             NaN              NaN  ...              2004
# 12           NaN             NaN              NaN  ...              2004
# 13           NaN             NaN              NaN  ...              2004
# 14           NaN             NaN              NaN  ...              2004
# 15           NaN             NaN              NaN  ...              2004
# 16           NaN             NaN              NaN  ...              2004
# 17           NaN             NaN              NaN  ...              2004
# 18           NaN             NaN              NaN  ...              2004
# 19           NaN             NaN              NaN  ...              2004
# 20           NaN             NaN              NaN  ...              2020
# 21           NaN             NaN              NaN  ...   January 1, 2020
# 22           NaN             NaN              NaN  ...  January 19, 2020
# 24           NaN             NaN              NaN  ...  January 22, 2020
# 26           NaN             NaN              NaN  ...  January 24, 2020
# 27           NaN             NaN              NaN  ...  January 26, 2020
# 29           NaN             NaN              NaN  ...              2020
# 30           NaN             NaN              NaN  ...              2020
# 31           NaN             NaN              NaN  ...              2020
# 32           NaN             NaN              NaN  ...              2020
# ..           ...             ...              ...  ...               ...
# 192          NaN             NaN              NaN  ...              2020
# 193          NaN             NaN              NaN  ...              2014
# 194          NaN             NaN              NaN  ...              2014
# 195          NaN             NaN              NaN  ...              2014
# 196          NaN             NaN              NaN  ...              2014
# 197          NaN             NaN              NaN  ...              2007
# 198          NaN             NaN              NaN  ...              2010
# 199          NaN             NaN              NaN  ...              2015
# 200          NaN             NaN              NaN  ...              2010
# 202          NaN             NaN              NaN  ...              2016
# 203          NaN             NaN              NaN  ...              2015
# 204          NaN             NaN              NaN  ...              2015
# 205          NaN             NaN              NaN  ...              2015
# 206          NaN             NaN              NaN  ...              2015
# 207          NaN             NaN              NaN  ...              2016
# 208          NaN             NaN              NaN  ...              2016
# 209          NaN             NaN              NaN  ...              2020
# 210          NaN             NaN              NaN  ...              2020
# 211          NaN             NaN              NaN  ...              2020
# 212          NaN             NaN              NaN  ...              2020
# 213          NaN             NaN              NaN  ...              2020
# 214          NaN             NaN              NaN  ...              2020
# 215          NaN             NaN              NaN  ...              2020
# 216          NaN             NaN              NaN  ...              2020
# 220          NaN             NaN              NaN  ...              2020
# 225         39.0            93.0              NaN  ...              2020
# 250          NaN            98.0              NaN  ...              2020
# 253          NaN             NaN              NaN  ...              2020
# 254          NaN             NaN              NaN  ...              2020
# 267         38.3             NaN             6.91  ...              2020
#
#                                               location  folder  \
# 0          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 3          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4    Changhua Christian Hospital, Changhua City, Ta...  images
# 5    Changhua Christian Hospital, Changhua City, Ta...  images
# 6                                                  NaN  images
# 7    Wuhan Jinyintan Hospital, Wuhan, Hubei Provinc...  images
# 8    Wuhan Jinyintan Hospital, Wuhan, Hubei Provinc...  images
# 9       Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 10      Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 11      Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 12      Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 13      Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 14      Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 15      Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 16      Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 17      Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 18      Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 19      Mount Sinai Hospital, Toronto, Ontario, Canada  images
# 20   Sunnybrook Health Sciences Centre, Toronto, On...  images
# 21   Tongji Medical College, Wuhan, Hubei Province,...  images
# 22                   Snohomish County, Washington, USA  images
# 24                   Snohomish County, Washington, USA  images
# 26                   Snohomish County, Washington, USA  images
# 27                   Snohomish County, Washington, USA  images
# 29                                                 NaN  images
# 30                                                 NaN  images
# 31                                                 NaN  images
# 32                                                 NaN  images
# ..                                                 ...     ...
# 192                                              Spain  images
# 193                                          Australia  images
# 194                                       Cairo, Egypt  images
# 195                                       Cairo, Egypt  images
# 196                                       Cairo, Egypt  images
# 197                                                NaN  images
# 198                                                NaN  images
# 199                                                NaN  images
# 200                                                NaN  images
# 202                                                NaN  images
# 203                                                NaN  images
# 204                                                NaN  images
# 205                                                NaN  images
# 206                                                NaN  images
# 207                                                NaN  images
# 208                                                NaN  images
# 209                                                NaN  images
# 210                                                NaN  images
# 211                                                NaN  images
# 212                                                NaN  images
# 213                                                NaN  images
# 214                                                NaN  images
# 215                                                NaN  images
# 216                                                NaN  images
# 220                                              Spain  images
# 225                                              Italy  images
# 250                                              Italy  images
# 253                                                NaN  images
# 254                                                NaN  images
# 267                                      Zigong, China  images
#
#                                               filename  \
# 0    auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...
# 1    auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...
# 2    auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...
# 3    auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...
# 4                                nejmc2001573_f1a.jpeg
# 5                                nejmc2001573_f1b.jpeg
# 6                                       ARDSSevere.png
# 7                                    lancet-case2a.jpg
# 8                                    lancet-case2b.jpg
# 9    SARS-10.1148rg.242035193-g04mr34g0-Fig8a-day0....
# 10   SARS-10.1148rg.242035193-g04mr34g0-Fig8b-day5....
# 11   SARS-10.1148rg.242035193-g04mr34g0-Fig8c-day10...
# 12   SARS-10.1148rg.242035193-g04mr34g04a-Fig4a-day...
# 13   SARS-10.1148rg.242035193-g04mr34g04b-Fig4b-day...
# 14   SARS-10.1148rg.242035193-g04mr34g05x-Fig5-day9...
# 15   SARS-10.1148rg.242035193-g04mr34g07a-Fig7a-day...
# 16   SARS-10.1148rg.242035193-g04mr34g07b-Fig7b-day...
# 17   SARS-10.1148rg.242035193-g04mr34g09a-Fig9a-day...
# 18   SARS-10.1148rg.242035193-g04mr34g09b-Fig9b-day...
# 19   SARS-10.1148rg.242035193-g04mr34g09c-Fig9c-day...
# 20                1-s2.0-S0140673620303706-fx1_lrg.jpg
# 21               nCoV-radiol.2020200269.fig1-day7.jpeg
# 22                            nejmoa2001191_f1-PA.jpeg
# 24                            nejmoa2001191_f3-PA.jpeg
# 26                               nejmoa2001191_f4.jpeg
# 27                            nejmoa2001191_f5-PA.jpeg
# 29                           ryct.2020200034.fig2.jpeg
# 30                      ryct.2020200034.fig5-day0.jpeg
# 31                      ryct.2020200034.fig5-day4.jpeg
# 32                      ryct.2020200034.fig5-day7.jpeg
# ..                                                 ...
# 192                          covid-19-pneumonia-28.png
# 193                         klebsiella-pneumonia-1.jpg
# 194           pneumocystis-jirovecii-pneumonia-3-1.jpg
# 195           pneumocystis-jirovecii-pneumonia-3-2.jpg
# 196           pneumocystis-jirovecii-pneumonia-3-3.jpg
# 197                       pneumocystis-pneumonia-1.jpg
# 198      X-ray_of_cyst_in_pneumocystis_pneumonia_1.jpg
# 199                       pneumocystis-pneumonia-8.jpg
# 200            pneumocystis-carinii-pneumonia-1-PA.jpg
# 202                      pneumocystis-pneumonia-12.png
# 203              pneumocystis-jiroveci-pneumonia-2.png
# 204             pneumocystis-jirovecii-pneumonia-2.jpg
# 205           pneumocystis-jiroveci-pneumonia-4-PA.png
# 206            pneumocystis-jiroveci-pneumonia-4-L.png
# 207                         legionella-pneumonia-1.png
# 208                         legionella-pneumonia-2.jpg
# 209  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...
# 210  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...
# 211  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...
# 212  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...
# 213  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...
# 214  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...
# 215  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...
# 216  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...
# 220  covid-19-pneumonia-evolution-over-a-week-1-day...
# 225          53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg
# 250                          covid-19-caso-70-1-PA.jpg
# 253          4e43e48d52c9e2d4c6c1fb9bc1544f_jumbo.jpeg
# 254                          covid-19-pneumonia-53.jpg
# 267  fff49165-b22d-4bb4-b9d1-d5d62c52436c.annot.ori...
#
#                                doi  \
# 0             10.1056/nejmc2001272
# 1             10.1056/nejmc2001272
# 2             10.1056/nejmc2001272
# 3             10.1056/nejmc2001272
# 4             10.1056/NEJMc2001573
# 5             10.1056/NEJMc2001573
# 6                              NaN
# 7    10.1016/S0140-6736(20)30211-7
# 8    10.1016/S0140-6736(20)30211-7
# 9             10.1148/rg.242035193
# 10            10.1148/rg.242035193
# 11            10.1148/rg.242035193
# 12            10.1148/rg.242035193
# 13            10.1148/rg.242035193
# 14            10.1148/rg.242035193
# 15            10.1148/rg.242035193
# 16            10.1148/rg.242035193
# 17            10.1148/rg.242035193
# 18            10.1148/rg.242035193
# 19            10.1148/rg.242035193
# 20   10.1016/S0140-6736(20)30370-6
# 21       10.1148/radiol.2020200269
# 22           10.1056/NEJMoa2001191
# 24           10.1056/NEJMoa2001191
# 26           10.1056/NEJMoa2001191
# 27           10.1056/NEJMoa2001191
# 29         10.1148/ryct.2020200034
# 30         10.1148/ryct.2020200034
# 31         10.1148/ryct.2020200034
# 32         10.1148/ryct.2020200034
# ..                             ...
# 192                            NaN
# 193                            NaN
# 194                            NaN
# 195                            NaN
# 196                            NaN
# 197                            NaN
# 198        10.4103/1817-1737.69106
# 199                            NaN
# 200                            NaN
# 202                            NaN
# 203                            NaN
# 204                            NaN
# 205                            NaN
# 206                            NaN
# 207                            NaN
# 208                            NaN
# 209                            NaN
# 210                            NaN
# 211                            NaN
# 212                            NaN
# 213                            NaN
# 214                            NaN
# 215                            NaN
# 216                            NaN
# 220                            NaN
# 225                            NaN
# 250                            NaN
# 253                            NaN
# 254                            NaN
# 267         10.1148/cases.20201394
#
#                                                    url      license  \
# 0    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# 1    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# 2    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# 3    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# 4    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# 5    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# 6    https://en.wikipedia.org/wiki/File:ARDSSevere.png          NaN
# 7    https://www.thelancet.com/journals/lancet/arti...          NaN
# 8    https://www.thelancet.com/journals/lancet/arti...          NaN
# 9       https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 10      https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 11      https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 12      https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 13      https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 14      https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 15      https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 16      https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 17      https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 18      https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 19      https://pubs.rsna.org/doi/10.1148/rg.242035193          NaN
# 20   https://www.sciencedirect.com/science/article/...          NaN
# 21   https://pubs.rsna.org/doi/10.1148/radiol.20202...          NaN
# 22   https://www.nejm.org/doi/full/10.1056/NEJMoa20...          NaN
# 24   https://www.nejm.org/doi/full/10.1056/NEJMoa20...          NaN
# 26   https://www.nejm.org/doi/full/10.1056/NEJMoa20...          NaN
# 27   https://www.nejm.org/doi/full/10.1056/NEJMoa20...          NaN
# 29   https://pubs.rsna.org/doi/full/10.1148/ryct.20...          NaN
# 30   https://pubs.rsna.org/doi/full/10.1148/ryct.20...          NaN
# 31   https://pubs.rsna.org/doi/full/10.1148/ryct.20...          NaN
# 32   https://pubs.rsna.org/doi/full/10.1148/ryct.20...          NaN
# ..                                                 ...          ...
# 192  https://radiopaedia.org/cases/covid-19-pneumon...  CC BY-NC-SA
# 193  https://radiopaedia.org/cases/klebsiella-pneum...  CC BY-NC-SA
# 194  https://radiopaedia.org/cases/pneumocystis-jir...  CC BY-NC-SA
# 195  https://radiopaedia.org/cases/pneumocystis-jir...  CC BY-NC-SA
# 196  https://radiopaedia.org/cases/pneumocystis-jir...  CC BY-NC-SA
# 197  https://radiopaedia.org/cases/pneumocystis-pne...        CC BY
# 198  https://en.wikipedia.org/wiki/File:X-ray_of_cy...        CC BY
# 199  https://radiopaedia.org/cases/pneumocystis-pne...  CC BY-NC-SA
# 200  https://radiopaedia.org/cases/pneumocystis-car...  CC BY-NC-SA
# 202  https://radiopaedia.org/cases/pneumocystis-pne...  CC BY-NC-SA
# 203  https://radiopaedia.org/cases/pneumocystis-jir...  CC BY-NC-SA
# 204  https://radiopaedia.org/cases/pneumocystis-jir...  CC BY-NC-SA
# 205  https://radiopaedia.org/cases/pneumocystis-jir...  CC BY-NC-SA
# 206  https://radiopaedia.org/cases/pneumocystis-jir...  CC BY-NC-SA
# 207  https://radiopaedia.org/cases/legionella-pneum...  CC BY-NC-SA
# 208  https://radiopaedia.org/cases/legionella-pneum...  CC BY-NC-SA
# 209  https://www.ams.edu.sg/colleges/radiologists/c...          NaN
# 210  https://www.ams.edu.sg/colleges/radiologists/c...          NaN
# 211  https://www.ams.edu.sg/colleges/radiologists/c...          NaN
# 212  https://www.ams.edu.sg/colleges/radiologists/c...          NaN
# 213  https://www.ams.edu.sg/colleges/radiologists/c...          NaN
# 214  https://www.ams.edu.sg/colleges/radiologists/c...          NaN
# 215  https://www.ams.edu.sg/colleges/radiologists/c...          NaN
# 216  https://www.ams.edu.sg/colleges/radiologists/c...          NaN
# 220  https://radiopaedia.org/cases/covid-19-pneumon...  CC BY-NC-SA
# 225  https://www.sirm.org/2020/03/28/covid-19-caso-66/          NaN
# 250  https://www.sirm.org/2020/03/30/covid-19-caso-70/          NaN
# 253  https://radiopaedia.org/cases/covid-19-pneumon...  CC BY-NC-SA
# 254  https://radiopaedia.org/cases/covid-19-pneumon...  CC BY-NC-SA
# 267  https://cases.rsna.org/case/8cc22815-ff15-4234...          NaN
#
#                                         clinical notes  \
# 0        infiltrate in the upper lobe of the left lung
# 1             progressive infiltrate and consolidation
# 2             progressive infiltrate and consolidation
# 3             progressive infiltrate and consolidation
# 4     diffuse infiltrates in the bilateral lower lungs
# 5    progressive diffuse interstitial opacities and...
# 6    Severe ARDS. Person is intubated with an OG in...
# 7    Case 2: chest x-ray obtained on Jan 6 (2A). Th...
# 8    Case 2: chest x-ray obtained on Jan 6 (2A). Th...
# 9    SARS in a 74-year-old man who developed sympto...
# 10   SARS in a 74-year-old man who developed sympto...
# 11   SARS in a 74-year-old man who developed sympto...
# 12   SARS in a 29-year-old woman who presented 7 da...
# 13   SARS in a 29-year-old woman who presented 7 da...
# 14   SARS in a 42-year-old woman who presented 9 da...
# 15   SARS in a 46-year-old woman who presented 5 da...
# 16   SARS in a 46-year-old woman who presented 5 da...
# 17   SARS in a 73-year-old woman who presented 17 d...
# 18   SARS in a 73-year-old woman who presented 17 d...
# 19   SARS in a 73-year-old woman who presented 17 d...
# 20   Chest x-ray shows bilateral peribronchovascula...
# 21   A, Chest radiograph obtained on day 7 after th...
# 22               No thoracic abnormalities were noted.
# 24   No acute intrathoracic plain-film abnormality ...
# 26   Increasing left basilar opacity was visible, a...
# 27   Stable streaky opacities in the lung bases wer...
# 29                                                 NaN
# 30   Chest radiographs of an elderly male patient f...
# 31   Chest radiographs of an elderly male patient f...
# 32   Chest radiographs of an elderly male patient f...
# ..                                                 ...
# 192  Attended the emergency department for progress...
# 193  Tachypneic and febrile. Extensive right upper ...
# 194  Adult female with positive HIV infection and l...
# 195  Adult female with positive HIV infection and l...
# 196  Adult female with positive HIV infection and l...
# 197  CXR of a patient with pneumocystis jiroveci pn...
# 198  If left untreated, chest X-ray may progress to...
# 199  Multifocal patchy opacities with diffuse retic...
# 200  There are diffuse bilaterally symmetric inters...
# 202  Sepsis, confusion. Found on ground.  Hazy opac...
# 203  AIDS stage of HIV infection. Syphilis treatmen...
# 204  History of HIV, loss of viral suppression, a f...
# 205  Flu-like illness. Rash. Diffuse interstitial o...
# 206  Flu-like illness. Rash. Diffuse interstitial o...
# 207  Febrile neutropenia. Extensive left lower lobe...
# 208  Presentation in ER with high fever, cough with...
# 209  Serial chest radiographs of patient who presen...
# 210  performed 7 days later showed interval resolut...
# 211  Serial chest radiographs of patient who presen...
# 212   performed 10 days later showed interval devel...
# 213  Serial chest radiographs of a patient who pres...
# 214  A follow-up radiograph (b) performed 7 days la...
# 215  Serial chest radiographs of a patient who pres...
# 216  Follow-up chest radiograph (b) performed 5 day...
# 220  This middle aged man attended the emergency ro...
# 225  Female patient, 71 years old, transferred to t...
# 250  multiple peribroncovasal parenchymal thickenin...
# 253  Patchy ill defined subpleural opacities are se...
# 254  Patchy ground glass opacities are present at b...
# 267  40-year-old man presented with a 10-day histor...
#
#                                            other notes Unnamed: 23
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# 5                                                  NaN         NaN
# 6                                                  NaN         NaN
# 7                                                  NaN         NaN
# 8                                                  NaN         NaN
# 9                                                  NaN         NaN
# 10                                                 NaN         NaN
# 11                                                 NaN         NaN
# 12                                                 NaN         NaN
# 13                                                 NaN         NaN
# 14                                                 NaN         NaN
# 15                                                 NaN         NaN
# 16                                                 NaN         NaN
# 17                                                 NaN         NaN
# 18                                                 NaN         NaN
# 19                                                 NaN         NaN
# 20                                                 NaN         NaN
# 21                                                 NaN         NaN
# 22                                                 NaN         NaN
# 24                                                 NaN         NaN
# 26                                                 NaN         NaN
# 27                                                 NaN         NaN
# 29                                                 NaN         NaN
# 30                                                 NaN         NaN
# 31                                                 NaN         NaN
# 32                                                 NaN         NaN
# ..                                                 ...         ...
# 192  Case courtesy of Dr Edgar Lorente, Radiopaedia...         NaN
# 193  Case courtesy of Dr Yune Kwong, Radiopaedia.or...         NaN
# 194  Case courtesy of Dr Fakhry Mahmoud Ebouda, Rad...         NaN
# 195  Case courtesy of Dr Fakhry Mahmoud Ebouda, Rad...         NaN
# 196  Case courtesy of Dr Fakhry Mahmoud Ebouda, Rad...         NaN
# 197  Case courtesy of Assoc Prof Frank Gaillard, Ra...         NaN
# 198  Credit to Carolyn M. Allen, Hamdan H. AL-Jahda...         NaN
# 199  Case courtesy of Dr Behrang Amini  , Radiopaed...         NaN
# 200  Case courtesy of Radswiki, Radiopaedia.org, rI...         NaN
# 202  Case courtesy of Dr Henry Knipe, Radiopaedia.o...         NaN
# 203  Case courtesy of Dr David Cuete, Radiopaedia.o...         NaN
# 204  Case courtesy of Dr Vikas Shah, Radiopaedia.or...         NaN
# 205  Case courtesy of Dr Henry Knipe, Radiopaedia.o...         NaN
# 206  Case courtesy of Dr Henry Knipe, Radiopaedia.o...         NaN
# 207  Case courtesy of Dr Henry Knipe, Radiopaedia.o...         NaN
# 208  Case courtesy of Dr Sigmund Stuppner, Radiopae...         NaN
# 209  Credit to College of Radiologists Singapore an...         NaN
# 210  Credit to College of Radiologists Singapore an...         NaN
# 211  Credit to College of Radiologists Singapore an...         NaN
# 212  Credit to College of Radiologists Singapore an...         NaN
# 213  Credit to College of Radiologists Singapore an...         NaN
# 214  Credit to College of Radiologists Singapore an...         NaN
# 215  Credit to College of Radiologists Singapore an...         NaN
# 216  Credit to College of Radiologists Singapore an...         NaN
# 220  Case courtesy of Dr Edgar Lorente, Radiopaedia...         NaN
# 225  Credit to Izzo Andrea, D'Aversa Lucia, Ceremon...         NaN
# 250  Credit to Sergio MargariASST Fatebenefratelli ...         NaN
# 253  Case courtesy of Dr Mohammad Taghi Niknejad, R...         NaN
# 254  Case courtesy of Dr Mohammad Taghi Niknejad, R...         NaN
# 267                                                NaN         NaN
#
# [150 rows x 24 columns]

# %%
# get non-COVID19 viral, bacteria, and COVID-19 infections from covid-chestxray-dataset
# stored as patient id, image filename and label
filename_label = {'normal': [], 'pneumonia': [], 'COVID-19': []}
count = {'normal': 0, 'pneumonia': 0, 'COVID-19': 0}
for index, row in csv.iterrows():
    f = row['finding']
    if f in mapping:
        count[mapping[f]] += 1
        entry = [int(row['patientid']), row['filename'], mapping[f]]
        filename_label[mapping[f]].append(entry)

print('Data distribution from covid-chestxray-dataset:')
print(count)
# Out:
# Data distribution from covid-chestxray-dataset:
# {'normal': 0, 'pneumonia': 24, 'COVID-19': 103}

# %%
# add covid-chestxray-dataset into COVIDx dataset
# since covid-chestxray-dataset doesn't have test dataset
# split into train/test by patientid
# for COVIDx:
# patient 8 is used as non-COVID19 viral test
# patient 31 is used as bacterial test
# patients 19, 20, 36, 42, 86 are used as COVID-19 viral test

for key in filename_label.keys():
    arr = np.array(filename_label[key])
    if arr.size == 0:
        continue
    # split by patients
    # num_diff_patients = len(np.unique(arr[:,0]))
    # num_test = max(1, round(split*num_diff_patients))
    # select num_test number of random patients
    if key == 'pneumonia':
        test_patients = ['8', '31']
    elif key == 'COVID-19':
        test_patients = ['19', '20', '36', '42', '86'] # random.sample(list(arr[:,0]), num_test)
    else: 
        test_patients = []
    print('Key: ', key)
    print('Test patients: ', test_patients)
    # go through all the patients
    for patient in arr:
        if patient[0] in test_patients:
            copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'test', patient[1]))
            test.append(patient)
            test_count[patient[2]] += 1
        else:
            copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'train', patient[1]))
            train.append(patient)
            train_count[patient[2]] += 1

print('test count: ', test_count)
print('train count: ', train_count)
# Out:
# Key:  pneumonia
# Test patients:  ['8', '31']
# Key:  COVID-19
# Test patients:  ['19', '20', '36', '42', '86']
# test count:  {'normal': 0, 'pneumonia': 5, 'COVID-19': 10}
# train count:  {'normal': 0, 'pneumonia': 19, 'COVID-19': 93}

# %%
# path to https://www.kaggle.com/c/rsna-pneumonia-detection-challenge
kaggle_datapath = '../rsna-pneumonia-detection-challenge'

# %%
# add normal and rest of pneumonia cases from https://www.kaggle.com/c/rsna-pneumonia-detection-challenge
csv_normal = pd.read_csv(os.path.join(kaggle_datapath, kaggle_csvname), nrows=None)
csv_pneu = pd.read_csv(os.path.join(kaggle_datapath, kaggle_csvname2), nrows=None)
patients = {'normal': [], 'pneumonia': []}

for index, row in csv_normal.iterrows():
    if row['class'] == 'Normal':
        patients['normal'].append(row['patientId'])

for index, row in csv_pneu.iterrows():
    if int(row['Target']) == 1:
        patients['pneumonia'].append(row['patientId'])

for key in patients.keys():
    arr = np.array(patients[key])
    if arr.size == 0:
        continue
    # split by patients 
    # num_diff_patients = len(np.unique(arr))
    # num_test = max(1, round(split*num_diff_patients))
    test_patients = np.load('rsna_test_patients_{}.npy'.format(key)) # random.sample(list(arr), num_test), download the .npy files from the repo.
    # np.save('rsna_test_patients_{}.npy'.format(key), np.array(test_patients))
    for patient in arr:
        ds = dicom.dcmread(os.path.join(kaggle_datapath, kaggle_imgpath, patient + '.dcm'))
        pixel_array_numpy = ds.pixel_array
        imgname = patient + '.png'
        if patient in test_patients:
            cv2.imwrite(os.path.join(savepath, 'test', imgname), pixel_array_numpy)
            test.append([patient, imgname, key])
            test_count[key] += 1
        else:
            cv2.imwrite(os.path.join(savepath, 'train', imgname), pixel_array_numpy)
            train.append([patient, imgname, key])
            train_count[key] += 1

print('test count: ', test_count)
print('train count: ', train_count)
# Out:
# test count:  {'normal': 885, 'pneumonia': 1058, 'COVID-19': 10}
# train count:  {'normal': 7966, 'pneumonia': 8521, 'COVID-19': 93}

# %%
# final stats
print('Final stats')
print('Train count: ', train_count)
print('Test count: ', test_count)
print('Total length of train: ', len(train))
print('Total length of test: ', len(test))
# Out:
# Final stats
# Train count:  {'normal': 7966, 'pneumonia': 8521, 'COVID-19': 93}
# Test count:  {'normal': 885, 'pneumonia': 1058, 'COVID-19': 10}
# Total length of train:  16580
# Total length of test:  1953

# %%
# run this cell when adding in new covid data from covid-chextxray-dataset

# load in current train/test information
'''train_filepath = 'train_split_v2.txt'
test_filepath = 'test_split_v2.txt'
file = open(train_filepath, 'r') 
trainfiles = file.readlines() 
trainfiles = np.array([line.split() for line in trainfiles])
file = open(test_filepath, 'r')
testfiles = file.readlines()
testfiles = np.array([line.split() for line in testfiles])

# find the new entries in csv 
new_entries = []
for key in filename_label.keys():
    arr = np.array(filename_label[key])
    if arr.size == 0:
        continue
    for patient in arr:
        if patient[1] not in trainfiles and patient[1] not in testfiles:
            # if key is normal, bacteria or viral add to train folder
            if key in ['normal', 'pneumonia']:
                copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'train', patient[1]))
                train.append(patient)
                train_count[patient[2]] += 1
            else: 
                new_entries.append(patient)
new_entries = np.array(new_entries)

# 10% of new entries should go into in test
if new_entries.size > 0:
    num_diff_patients = len(np.unique(new_entries[:,0]))
    num_test = max(1, round(split*num_diff_patients))

    i = 0
    used_i = []
    # insert patients who are already in dataset into the respective train/test
    for patient in new_entries:
        if patient[0] in trainfiles:
            copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'train', patient[1]))
            train.append(patient)
            train_count[patient[2]] += 1
            used_i.append(i)
        elif patient[0] in testfiles:
            copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'test', patient[1]))
            test.append(patient)
            test_count[patient[2]] += 1
            used_i.append(i)
        i += 1
    # delete patients who have already been inserted
    new_entries = np.delete(new_entries, used_i, axis=0)

    # select num_test number of random patients
    test_patients = random.sample(list(new_entries[:,0]), num_test)
    print('test patients: ', test_patients)
    # add to respective train/test folders
    for patient in new_entries:
        if patient[0] in test_patients:
            copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'test', patient[1]))
            test.append(patient)
            test_count[patient[2]] += 1
        else:
            copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'train', patient[1]))
            train.append(patient)
            train_count[patient[2]] += 1

print('added test count: ', test_count)
print('added train count: ', train_count)'''
# Out:
# "train_filepath = 'train_split_v2.txt'\ntest_filepath = 'test_split_v2.txt'\nfile = open(train_filepath, 'r') \ntrainfiles = file.readlines() \ntrainfiles = np.array([line.split() for line in trainfiles])\nfile = open(test_filepath, 'r')\ntestfiles = file.readlines()\ntestfiles = np.array([line.split() for line in testfiles])\n\n# find the new entries in csv \nnew_entries = []\nfor key in filename_label.keys():\n    arr = np.array(filename_label[key])\n    if arr.size == 0:\n        continue\n    for patient in arr:\n        if patient[1] not in trainfiles and patient[1] not in testfiles:\n            # if key is normal, bacteria or viral add to train folder\n            if key in ['normal', 'pneumonia']:\n                copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'train', patient[1]))\n                train.append(patient)\n                train_count[patient[2]] += 1\n            else: \n                new_entries.append(patient)\nnew_entries = np.array(new_entries)\n\n# 10% of new entries should go into in test\nif new_entries.size > 0:\n    num_diff_patients = len(np.unique(new_entries[:,0]))\n    num_test = max(1, round(split*num_diff_patients))\n\n    i = 0\n    used_i = []\n    # insert patients who are already in dataset into the respective train/test\n    for patient in new_entries:\n        if patient[0] in trainfiles:\n            copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'train', patient[1]))\n            train.append(patient)\n            train_count[patient[2]] += 1\n            used_i.append(i)\n        elif patient[0] in testfiles:\n            copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'test', patient[1]))\n            test.append(patient)\n            test_count[patient[2]] += 1\n            used_i.append(i)\n        i += 1\n    # delete patients who have already been inserted\n    new_entries = np.delete(new_entries, used_i, axis=0)\n\n    # select num_test number of random patients\n    test_patients = random.sample(list(new_entries[:,0]), num_test)\n    print('test patients: ', test_patients)\n    # add to respective train/test folders\n    for patient in new_entries:\n        if patient[0] in test_patients:\n            copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'test', patient[1]))\n            test.append(patient)\n            test_count[patient[2]] += 1\n        else:\n            copyfile(os.path.join(imgpath, patient[1]), os.path.join(savepath, 'train', patient[1]))\n            train.append(patient)\n            train_count[patient[2]] += 1\n\nprint('added test count: ', test_count)\nprint('added train count: ', train_count)"

# %%
# export to train and test csv
# format as patientid, filename, label, separated by a space
train_file = open("train_split_v2.txt","a") 
for sample in train:
    info = str(sample[0]) + ' ' + sample[1] + ' ' + sample[2] + '\n'
    train_file.write(info)

train_file.close()

test_file = open("test_split_v2.txt", "a")
for sample in test:
    info = str(sample[0]) + ' ' + sample[1] + ' ' + sample[2] + '\n'
    test_file.write(info)

test_file.close()
